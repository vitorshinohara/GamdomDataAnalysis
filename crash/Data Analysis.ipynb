# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('output 04-09.csv')
df.head()
# Out:
#    match_number  crashNumber  players  ma_bet  min_bet  total bet  \
# 0             1        34.74       16   25000       10      42883
# 1             2         1.39       14   11000       10      20239
# 2             3         3.34       18   30000       10      52659
# 3             4         2.10       14   10000       10      20566
# 4             5         1.20       13   25200       10      36249
#
#    total_profit
# 0        116258
# 1        -20056
# 2         41198
# 3        -17274
# 4        -35990

# %%
_df = df.values

st = StandardScaler()
_df = st.fit_transform(df.values)

x = df.values[:,0]
y = _df[:50,1]
plt.figure(figsize=(20,10))
plt.xlabel('Match Number')
plt.ylabel('Crash Number Normalized')
plt.grid(True)
plt.plot(x,_df[:,2], 'r')
plt.plot(x,_df[:,-1], 'g')

# %%
corr = df[['crashNumber', 'players', 'ma_bet', 'min_bet', 'total bet', 'total_profit']].corr()
sns.heatmap(corr, annot=True)

# %% [markdown]
# ### Seems that there is no pattern in this data :(

# %%
x = range(len(df['total_profit'].values))
y = df['total_profit'].values

# %%
total = 0
total_hist = []
for i in y:
    total += i
    total_hist.append(total)

    
profit_last_round = []

# %%
plt.figure(figsize=(20, 10))
plt.grid(True)
plt.plot(x,y, marker='x', label='Round profit')
plt.plot(x,total_hist, marker='x', label='Accumulated Profit')
plt.legend(fontsize=14)
plt.xticks(x,x, rotation=90)
plt.xlabel('Round')
plt.ylabel('Profit')

plt.show()
